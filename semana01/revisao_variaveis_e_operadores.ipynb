# %% [markdown]
# # Python - revisão - Variáveis e Operadores

# %% [markdown]
# **O que são funções?**
#
# Funções permitem reutilizar código.

# %%
def saudacao():
    print("Olá aluno!")

# %%
saudacao()
# Out:
# Olá aluno!

# %% [markdown]
# ### Funções com parâmetros

# %%
def saudacao(nome):
    print("Olá", nome)

# %%
saudacao("Maria")

# %% [markdown]
# ### Funções com retorno

# %%
def soma(a, b):
    return a + b

# %%
resultado = soma(10, 5)
print(resultado)

# %%
soma(10, 5)
# Out:
# 15

# %% [markdown]
# É de extrema importância saber documentar as funções

# %% [markdown]
# **EXERCÍCIO 01**
#
# Crie uma função que receba dois números e retorne a multiplicação:

# %%
def multi(a,b):
  r = a*b
  return r

multi(4,5)
# Out:
# 20

# %% [markdown]
# **EXERCÍCIO 02:**
#
# Crie uma função que calcule a média entre dois números

# %%
def media (a,b):
  media = (a+b)/2
  return media

media(8,8)
# Out:
# 8.0

# %% [markdown]
# **EXERCÍCIO 03:**
#
# Crie uma função que recebe a medida de dois catetos e retorna a hipotenusa de uma triângulo retângulo

# %%
def hp(cat1, cat2):
  raiz = (cat1**2 ) + (cat2**2)
  hip = raiz**0.5
  return int(hip)

hp(3,4)
# Out:
# 5

# %%
import math
math.sqrt(9)
# Out:
# 3.0

# %% [markdown]
# **EXERCÍCIO 04:**
#
# Crie uma função que retorna se um número é par ou impar

# %%
def verifica(a):
  resto = 2%2
  return a
verifica(8)
# Out:
# 8

# %% [markdown]
# **EXERCÍCIO 05:**
#
#  Crie uma função soma_imposto(taxa_imposto, custo) que altere o valor do custo incluindo o imposto (ex: taxa de 10% sobre 100 retorna 110)

# %%
def soma_imposto(taxa, custo):
  '''
        par:
        taxa  = taxa de juros em porcetagem
        custo = custo de producao
  '''
  taxa = (taxa/100)*custo
  total = custo+taxa
  return total
soma_imposto(10,100)
# Out:
# 110.0

# %% [markdown]
# EXERCÍCIO 06:
# Crie uma função que tenha como parâmetro 4 notas de alunos e retorne se ele foi aprovado ou não (considerando que a média de aprovação seja 6)

# %%
def verificacao(not1, not2, not3, not4):
  media = (not1+not2+not3+not4)/4
  if media >= 6:
    print('Aprovado')
  else:
    printf('Reprovado')
  return media

# %%
not1 = 5
not2 = 5
not3 = 7
not4 = 8

# %%
verificacao(not1, not2, not3, not4)
# Out:
# Aprovado
# 6.25
